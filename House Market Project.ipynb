# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\geono\OneDrive\Έγγραφα\PythonLesson\Py-DS-ML-Bootcamp-master\TensorFlow_FILES\TensorFlow_FILES\DATA\kc_house_data.csv")

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %% [markdown]
# EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     21597 non-null  int64
#  9   view           21597 non-null  int64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  int64
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   21597 non-null  int64
#  16  zipcode        21597 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
plt.figure(figsize=(15,6))
sns.distplot(df['price'])
plt.xlabel("price in milion")
# Out:
# C:\Users\geono\AppData\Local\Temp\ipykernel_9376\3743957828.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# Text(0.5, 0, 'price in milion')

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df[['price','bedrooms','bathrooms','sqft_living','sqft_lot', 'floors', 'waterfront', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated']].corr(),annot=True,cmap='viridis')
# Out:
# <Axes: >

# %%
df.drop('date',axis=1).corr()['price'].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.701917
# grade            0.667951
# sqft_above       0.605368
# sqft_living15    0.585241
# bathrooms        0.525906
# view             0.397370
# sqft_basement    0.323799
# bedrooms         0.308787
# lat              0.306692
# waterfront       0.266398
# floors           0.256804
# yr_renovated     0.126424
# sqft_lot         0.089876
# sqft_lot15       0.082845
# yr_built         0.053953
# condition        0.036056
# long             0.022036
# id              -0.016772
# zipcode         -0.053402
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='price',y='sqft_living',data=df)
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y='price',x='bedrooms',data=df,palette='viridis')
# Out:
# C:\Users\geono\AppData\Local\Temp\ipykernel_9376\2422399938.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y='price',x='bedrooms',data=df,palette='viridis')
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(y='lat',x='long',data=df,hue='price')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(y='price',x='long',data=df)
# Out:
# <Axes: xlabel='long', ylabel='price'>

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='price',y='lat',data=df)
# Out:
# <Axes: xlabel='price', ylabel='lat'>

# %%
df['price'].sort_values(ascending=False)
# Out:
# 7245     7700000.0
# 3910     7060000.0
# 9245     6890000.0
# 4407     5570000.0
# 1446     5350000.0
#            ...
# 2139       82500.0
# 8267       82000.0
# 16184      81000.0
# 465        80000.0
# 15279      78000.0
# Name: price, Length: 21597, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='long',y='lat',data=df[df['price']<3000000],hue='price',alpha=0.8,palette='coolwarm')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
sns.boxplot(x='waterfront',y='price',data=df)
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %%
df=df.drop('id',axis=1)

# %%
df.head()
# Out:
#          date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  10/13/2014  221900.0         3       1.00         1180      5650     1.0
# 1   12/9/2014  538000.0         3       2.25         2570      7242     2.0
# 2   2/25/2015  180000.0         2       1.00          770     10000     1.0
# 3   12/9/2014  604000.0         4       3.00         1960      5000     1.0
# 4   2/18/2015  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df['year']=df['date'].dt.year

# %%
df['month']=df['date'].dt.month

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %% [markdown]
# Lets see if year,month are usefull data:

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='month',y='price',data=df,palette='coolwarm')
plt.xlabel('Month')
plt.ylabel('Price Of The House')
# Out:
# C:\Users\geono\AppData\Local\Temp\ipykernel_9376\3963113202.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='month',y='price',data=df,palette='coolwarm')
# Text(0, 0.5, 'Price Of The House')

# %%
plt.figure(figsize=(10,7))
plt.plot(df.groupby('month').mean()['price'])
plt.xlabel('Month')
plt.ylabel('Price Of The House')
# Out:
# Text(0, 0.5, 'Price Of The House')

# %%
sns.boxplot(x='year',y='price',data=df,palette='viridis')
# Out:
# C:\Users\geono\AppData\Local\Temp\ipykernel_9376\330903362.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='year',y='price',data=df,palette='viridis')
# <Axes: xlabel='year', ylabel='price'>

# %%
df.groupby('year').mean()['price']
# Out:
# year
# 2014    539350.911777
# 2015    542279.005878
# Name: price, dtype: float64

# %%
df.groupby('year').mean()['price'].plot()
# Out:
# <Axes: xlabel='year'>

# %%
df=df.drop('date',axis=1)

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year', 'month'],
#       dtype='object')

# %%
sns.heatmap(df[['lat','long','zipcode']].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# There is only corr of zipcode and lat, so we don need them fro now:

# %%
df=df.drop('zipcode',axis=1)

# %%
df['yr_renovated'].value_counts()
# Out:
# yr_renovated
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: count, Length: 70, dtype: int64

# %% [markdown]
# Create A Model:

# %%
X=df.drop('price',axis=1).values#tf doesn work with dfs so we need only the values

# %%
y=df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
X_train=scaler.fit_transform(X_train)
#we dont fit the X_test. The reason is that we dont want our model to have information about the X_test data. 
X_test=scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (15117, 19)

# %%
model=Sequential()
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train,validation_data=(X_test,y_test),batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 446508335104.0000 - val_loss: 418919383040.0000
# Epoch 2/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 424810119168.0000 - val_loss: 414772035584.0000
# Epoch 3/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 426258956288.0000 - val_loss: 376113496064.0000
# Epoch 4/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 353449476096.0000 - val_loss: 245617524736.0000
# Epoch 5/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 219258486784.0000 - val_loss: 111250071552.0000
# Epoch 6/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 103057973248.0000 - val_loss: 94235336704.0000
# Epoch 7/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 90869014528.0000 - val_loss: 92751847424.0000
# Epoch 8/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 90903175168.0000 - val_loss: 91192868864.0000
# Epoch 9/400
# ...

# %%
losses=pd.DataFrame(model.history.history)

# %%
plt.figure(figsize=(15,6))
sns.lineplot(losses)
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,explained_variance_score

# %%
predictions=model.predict(X_test)
# Out:
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
mean_squared_error(predictions,y_test)
# Out:
# 27507080174.549854

# %%
mean_absolute_error(predictions,y_test)
# Out:
# 102644.36279658564

# %%
df['price'].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
5.402966e+05
# Out:
# 540296.6

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.7925896836419929

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test,predictions)
plt.plot(y_test,y_test,color='red')

# %%
single_house=df.iloc[0].drop('price').values

# %%
single_house=single_house.reshape(-1,19)

# %%
single_house=scaler.transform(single_house)

# %%
model.predict(single_house)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# array([[292091.16]], dtype=float32)

# %%
df.iloc[0]['price']
# Out:
# 221900.0

# %%
print('We are of about:', 280921.4-221900.0)
# Out:
# We are of about: 59021.40000000002

# %% [markdown]
# Lets retrain our model. Now we drop the outliers:

# %%
X_new=df[df['price']<2000000.0].drop('price',axis=1).values
y_new=df[df['price']<2000000.0]['price'].values

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X_new, y_new, test_size=0.3, random_state=101)

# %%
X_train2=scaler.fit_transform(X_train2)
X_test2=scaler.transform(X_test2)

# %%
model2=Sequential()
model2.add(Dense(19,activation='relu'))
model2.add(Dense(19,activation='relu'))
model2.add(Dense(19,activation='relu'))
model2.add(Dense(19,activation='relu'))
model2.add(Dense(19,activation='relu'))
model2.add(Dense(1))
model2.compile(optimizer='adam',loss='mse')

# %%
model2.fit(x=X_train2,y=y_train2,validation_data=(X_test2,y_test2),batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 350105337856.0000 - val_loss: 354788638720.0000
# Epoch 2/400
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 347520860160.0000 - val_loss: 336666263552.0000
# Epoch 3/400
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 303149285376.0000 - val_loss: 135741718528.0000
# Epoch 4/400
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 89381928960.0000 - val_loss: 57054703616.0000
# Epoch 5/400
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 51206799360.0000 - val_loss: 55512776704.0000
# Epoch 6/400
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 51991707648.0000 - val_loss: 53950861312.0000
# Epoch 7/400
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 49001594880.0000 - val_loss: 52380016640.0000
# Epoch 8/400
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 47978532864.0000 - val_loss: 50767400960.0000
# Epoch 9/400
# ...

# %%
loss2=pd.DataFrame(model2.history.history)

# %%
plt.figure(figsize=(15,7))
sns.lineplot(loss2)
# Out:
# <Axes: >

# %%
predictions2=model2.predict(X_test2)
# Out:
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
mean_absolute_error(y_test2,predictions2)
# Out:
# 96059.2250199665

# %%
explained_variance_score(y_test2,predictions2)
# Out:
# 0.7605875312617262

# %%
help(explained_variance_score)
# Out:
# Help on function explained_variance_score in module sklearn.metrics._regression:
#
# explained_variance_score(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average', force_finite=True)
#     Explained variance regression score function.
#
#     Best possible score is 1.0, lower values are worse.
#
#     In the particular case when ``y_true`` is constant, the explained variance
#     score is not finite: it is either ``NaN`` (perfect predictions) or
#     ``-Inf`` (imperfect predictions). To prevent such non-finite numbers to
#     pollute higher-level experiments such as a grid search cross-validation,
#     by default these cases are replaced with 1.0 (perfect predictions) or 0.0
#     (imperfect predictions) respectively. If ``force_finite``
#     is set to ``False``, this score falls back on the original :math:`R^2`
#     definition.
#
#     .. note::
#        The Explained Variance score is similar to the
# ...

# %%
data_to_test=df.iloc[0].drop('price').values

# %%
data_to_test=data_to_test.reshape(-1,19)

# %%
data_to_test=scaler.transform(data_to_test)

# %%
model2.predict(data_to_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# array([[279916.9]], dtype=float32)

# %%
plt.scatter(predictions2,y_test2)
plt.plot(y_test2,y_test2,'r')
